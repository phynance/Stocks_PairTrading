# %%
# Bollinger Band Mean Reversion Strategy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
import statsmodels.tsa.stattools as ts
#import statsmodels.tsa.vector_ar.vecm as vm

# %%
# df=pd.read_csv('inputData_GLD_USO.csv')
# df['Date']=pd.to_datetime(df['Date'],  format='%Y%m%d').dt.date # remove HH:MM:SS
# df.set_index('Date', inplace=True)

df=pd.read_csv('KO_PEP_last_10_years.csv',index_col="Date")

# %%
df.head()
# Out:
#                    KO        PEP
# Date
# 2014-01-02  29.140577  60.635101
# 2014-01-03  28.997244  60.738506
# 2014-01-06  28.861074  60.768051
# 2014-01-07  28.947075  61.654297
# 2014-01-08  28.624563  61.477047

# %%
lookback=252
hedgeRatio=np.full(df.shape[0], np.nan)

    
for t in np.arange(lookback, len(hedgeRatio)+1):
    regress_results=sm.ols(formula="PEP ~ KO", data=df[(t-lookback):t]).fit() # Note this can deal with NaN in top row
    hedgeRatio[t-1]=regress_results.params[1]

# %%
hedgeRatio[200:300]
# Out:
# array([       nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan, 2.89929352, 2.89805076, 2.8949351 , 2.88825278,
#        2.88561471, 2.88381886, 2.88320696, 2.8838484 , 2.88359382,
#        2.88377014, 2.88503681, 2.88700898, 2.88673951, 2.8843596 ,
#        2.88310327, 2.88485456, 2.88793673, 2.89095922, 2.89286582,
# ...

# %%
ts.add_constant(-hedgeRatio)[:, [1,0]]
# Out:
# array([[        nan,  1.        ],
#        [        nan,  1.        ],
#        [        nan,  1.        ],
#        ...,
#        [-0.85102969,  1.        ],
#        [-0.84539946,  1.        ],
#        [-0.84614031,  1.        ]])

# %%
yport=np.sum(ts.add_constant(-hedgeRatio)[:, [1,0]]*df, axis=1) # -HR *KO + PEP
#yport=np.sum(ts.add_constant(-hedgeRatio)*df, axis=1) #double check the order

yport.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
MA=yport.rolling(lookback).mean()
MSTD=yport.rolling(lookback).std()
zScore=(yport-MA)/MSTD
zScore[lookback:].plot()


z_scoreThreshold = 2.5

plt.axhline(zScore.mean())
plt.axhline(z_scoreThreshold, color='red')
plt.axhline(-z_scoreThreshold, color='green')
plt.show()

# %%
# Bollinger band strategy
entryZscore=z_scoreThreshold
exitZscore=0

longsEntry=zScore < -entryZscore
longsExit =zScore > -exitZscore
shortsEntry=zScore > entryZscore
shortsExit =zScore < exitZscore

numUnitsLong    =np.zeros(longsEntry.shape)
numUnitsLong[:] =np.nan
numUnitsShort   =np.zeros(shortsEntry.shape)
numUnitsShort[:]=np.nan

numUnitsLong[0]=0
numUnitsLong[longsEntry]=1
numUnitsLong[longsExit]=0
numUnitsLong=pd.DataFrame(numUnitsLong)
numUnitsLong.fillna(method='ffill', inplace=True)

numUnitsShort[0]=0
numUnitsShort[shortsEntry]=-1
numUnitsShort[shortsExit]=0
numUnitsShort=pd.DataFrame(numUnitsShort)
numUnitsShort.fillna(method='ffill', inplace=True)

numUnits=numUnitsLong+numUnitsShort

# %%
positions=pd.DataFrame(np.tile(numUnits.values, [1, 2]) * ts.add_constant(-hedgeRatio)[:, [1,0]] *df) 
#  [hedgeRatio -ones(size(hedgeRatio))] is the shares allocation, 
# [hedgeRatio -ones(size(hedgeRatio))].*y2 is the dollar capital allocation, while positions is the dollar capital in each ETF.

# %%
positions[100:120]
# Out:
#             KO  PEP
# Date
# 2014-05-28 NaN  0.0
# 2014-05-29 NaN  0.0
# 2014-05-30 NaN  0.0
# 2014-06-02 NaN  0.0
# 2014-06-03 NaN  0.0
# 2014-06-04 NaN  0.0
# 2014-06-05 NaN  0.0
# 2014-06-06 NaN  0.0
# 2014-06-09 NaN  0.0
# 2014-06-10 NaN  0.0
# 2014-06-11 NaN  0.0
# 2014-06-12 NaN  0.0
# 2014-06-13 NaN  0.0
# 2014-06-16 NaN  0.0
# 2014-06-17 NaN  0.0
# 2014-06-18 NaN  0.0
# 2014-06-19 NaN  0.0
# 2014-06-20 NaN  0.0
# 2014-06-23 NaN  0.0
# 2014-06-24 NaN  0.0

# %%
positions.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pnl=np.sum((positions.shift().values)*(df.pct_change().values), axis=1) # daily P&L of the strategy
ret=pnl/np.sum(np.abs(positions.shift()), axis=1)
pd.DataFrame((np.cumprod(1+ret)-1)).plot()

print('APR=%f Sharpe=%f' % (np.prod(1+ret)**(252/len(ret))-1, np.sqrt(252)*np.mean(ret)/np.std(ret)))
# Out:
# APR=-0.018258 Sharpe=-0.989796
